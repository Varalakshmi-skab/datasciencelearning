# %% [markdown]
# <a href="https://colab.research.google.com/github/Varalakshmi-skab/datasciencelearning/blob/main/Regressor_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np

# %%
housing=fetch_california_housing(as_frame=True)

# %%
housing

# %%
df=housing.frame

# %%
df

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
plt.title("Heat map")
plt.show()

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'MedHouseVal'],
#       dtype='object')

# %%
X=df.drop("MedHouseVal",axis=1) #Independeny features
Y=df["MedHouseVal"] #Dependent features

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
model=GradientBoostingRegressor(
    n_estimators=100,
    random_state=42
)
model.fit(X_train,Y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred=model.predict(X_test)

# %%
r2score=r2_score(Y_test,y_pred)
print("R2 Score is",r2score)
# Out:
# R2 Score is 0.7756446042829697

# %%
mse=mean_squared_error(Y_test,y_pred)
print("MSE is",mse)
# Out:
# MSE is 0.2939973248643864

# %%
rmse=np.sqrt(mse)
print("RMSE is",rmse)
# Out:
# RMSE is 0.5422152016168362

# %%
mae=mean_absolute_error(Y_test,y_pred)
print("MAE is",mae)
# Out:
# MAE is 0.3716425690425596

# %%
from xgboost import XGBRegressor
model=XGBRegressor(
    n_estimators=100,
    random_state=42
)
model.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
Y_pred=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
r2score=r2_score(Y_test,Y_pred)
print("R2 Score is",r2score)
# Out:
# R2 Score is 0.8301370561019205

# %%
mse=mean_squared_error(Y_test,Y_pred)
print("MSE is",mse)
# Out:
# MSE is 0.2225899267544737

# %%
rmse=np.sqrt(mse)
print("RMSE is",rmse)
# Out:
# RMSE is 0.4717943691423984

# %%
mae=mean_absolute_error(Y_test,Y_pred)
print("MAE is",mae)
# Out:
# MAE is 0.30957335413783094

# %%
from lightgbm import LGBMRegressor
model2=LGBMRegressor(
    n_estimators=100,
    random_state=42,
    verbose=-1
)
model2.fit(X_train,Y_train)
# Out:
# LGBMRegressor(random_state=42, verbose=-1)

# %%
Y_pred=model2.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
r2score=r2_score(Y_test,Y_pred)
print("R2 Score is",r2score)
mse=mean_squared_error(Y_test,Y_pred)
print("MSE is",mse)
rmse=np.sqrt(mse)
print("RMSE is",rmse)
mae=mean_absolute_error(Y_test,Y_pred)
print("MAE is",mae)
# Out:
# R2 Score is 0.8360449251645318
# MSE is 0.21484820209255617
# RMSE is 0.46351720797890145
# MAE is 0.30775487567243004

# %%
# !pip install catboost

# %%
from catboost import CatBoostRegressor
model3=CatBoostRegressor(
    iterations=300,
    random_state=42
)
model3.fit(X_train,Y_train)

# %%
Y_pred=model3.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
r2score=r2_score(Y_test,Y_pred)
print("R2 Score is",r2score)
mse=mean_squared_error(Y_test,Y_pred)
print("MSE is",mse)
rmse=np.sqrt(mse)
print("RMSE is",rmse)
mae=mean_absolute_error(Y_test,Y_pred)
print("MAE is",mae)
# Out:
# R2 Score is 0.8417505300829131
# MSE is 0.2073715261812139
# RMSE is 0.4553806387860752
# MAE is 0.3011312261222796
