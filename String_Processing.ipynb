# %% [markdown]
# <a href="https://colab.research.google.com/github/Varalakshmi-skab/datasciencelearning/blob/main/String_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # string processing in pandas means perfroming operations on text(string)
# # data stored in dataframe columns using pandas string functions
# cHevuri
# 1000,
# 50
# chevurisanthosh@gmail.com
# chevurisantosh@outlook.com
# "    santosh"

# %%
s = "   lahari"
#if we want to remove spaces we will use strip method
#lstrip it will remove spaces in left side
#rstrip it will remove spaces in right side only
#strip #it will remove spaces from both sides
print(s.strip())
# Out:
# lahari

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets for datascience/string_processing_dataset.csv")

# %%
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  Vijayawada         Rs 1000
# 1           RAJU KUMAR      RAJU@YAHOO.COM   HYDERABAD            $250
# 2          kiran reddy     kiran@gmail.com      vizag         Rs 3,500
# 3        SURESH BABU    suresh@outlook.com      Guntur          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["email"] = df["email"].str.lower() #we are converting into the lower case
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  Vijayawada         Rs 1000
# 1           RAJU KUMAR      raju@yahoo.com   HYDERABAD            $250
# 2          kiran reddy     kiran@gmail.com      vizag         Rs 3,500
# 3        SURESH BABU    suresh@outlook.com      Guntur          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
#convert cities into uppercase
df["city"] = df["city"].str.upper()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA         Rs 1000
# 1           RAJU KUMAR      raju@yahoo.com   HYDERABAD            $250
# 2          kiran reddy     kiran@gmail.com      VIZAG         Rs 3,500
# 3        SURESH BABU    suresh@outlook.com      GUNTUR          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
#converting customer_name column into title
df["customer_name"] = df["customer_name"].str.title()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA         Rs 1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD            $250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG         Rs 3,500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date
# 0  9876543210      PRD-101  12-Jan-2024
# 1  9123456789      PRD-202  05-Feb-2024
# 2  9988776655      PRD-303  18-Mar-2024
# 3  9871234567      PRD-404  22-Apr-2024
# 4  9012345678      PRD-505  30-May-2024

# %%
df["name_length"] = df["customer_name"].str.len()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA         Rs 1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD            $250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG         Rs 3,500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date  name_length
# 0  9876543210      PRD-101  12-Jan-2024           19
# 1  9123456789      PRD-202  05-Feb-2024           10
# 2  9988776655      PRD-303  18-Mar-2024           13
# 3  9871234567      PRD-404  22-Apr-2024           13
# 4  9012345678      PRD-505  30-May-2024           12

# %%
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA         Rs 1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD            $250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG         Rs 3,500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI          Rs 750
#
#         phone product_code    join_date  name_length
# 0  9876543210      PRD-101  12-Jan-2024           19
# 1  9123456789      PRD-202  05-Feb-2024           10
# 2  9988776655      PRD-303  18-Mar-2024           13
# 3  9871234567      PRD-404  22-Apr-2024           13
# 4  9012345678      PRD-505  30-May-2024           12

# %%
# regex = false tella pandas to treat the value as normal text and not as a special pattern

# %%
df["purchase_amount"] = df["purchase_amount"].str.replace("Rs ", "", regex= False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD            $250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG            3,500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR          $1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length
# 0  9876543210      PRD-101  12-Jan-2024           19
# 1  9123456789      PRD-202  05-Feb-2024           10
# 2  9988776655      PRD-303  18-Mar-2024           13
# 3  9871234567      PRD-404  22-Apr-2024           13
# 4  9012345678      PRD-505  30-May-2024           12

# %%
df["purchase_amount"] = df["purchase_amount"].str.replace("$", "", regex= False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG            3,500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR           1,200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length
# 0  9876543210      PRD-101  12-Jan-2024           19
# 1  9123456789      PRD-202  05-Feb-2024           10
# 2  9988776655      PRD-303  18-Mar-2024           13
# 3  9871234567      PRD-404  22-Apr-2024           13
# 4  9012345678      PRD-505  30-May-2024           12

# %%
df["purchase_amount"] = df["purchase_amount"].str.replace(",", "", regex= False)
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length
# 0  9876543210      PRD-101  12-Jan-2024           19
# 1  9123456789      PRD-202  05-Feb-2024           10
# 2  9988776655      PRD-303  18-Mar-2024           13
# 3  9871234567      PRD-404  22-Apr-2024           13
# 4  9012345678      PRD-505  30-May-2024           12

# %%
df["is_mail"] = df["email"].str.contains("gmail")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length  is_mail
# 0  9876543210      PRD-101  12-Jan-2024           19     True
# 1  9123456789      PRD-202  05-Feb-2024           10    False
# 2  9988776655      PRD-303  18-Mar-2024           13     True
# 3  9871234567      PRD-404  22-Apr-2024           13    False
# 4  9012345678      PRD-505  30-May-2024           12     True

# %%
df["endswith"] = df["email"].str.endswith(".com")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length  is_mail  endswith
# 0  9876543210      PRD-101  12-Jan-2024           19     True      True
# 1  9123456789      PRD-202  05-Feb-2024           10    False      True
# 2  9988776655      PRD-303  18-Mar-2024           13     True      True
# 3  9871234567      PRD-404  22-Apr-2024           13    False      True
# 4  9012345678      PRD-505  30-May-2024           12     True      True

# %%
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length  is_mail  endswith
# 0  9876543210      PRD-101  12-Jan-2024           19     True      True
# 1  9123456789      PRD-202  05-Feb-2024           10    False      True
# 2  9988776655      PRD-303  18-Mar-2024           13     True      True
# 3  9871234567      PRD-404  22-Apr-2024           13    False      True
# 4  9012345678      PRD-505  30-May-2024           12     True      True

# %%
df["email_parts"] = df["email"].str.split("@")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length  is_mail  endswith  \
# 0  9876543210      PRD-101  12-Jan-2024           19     True      True
# 1  9123456789      PRD-202  05-Feb-2024           10    False      True
# 2  9988776655      PRD-303  18-Mar-2024           13     True      True
# 3  9871234567      PRD-404  22-Apr-2024           13    False      True
# 4  9012345678      PRD-505  30-May-2024           12     True      True
#
#              email_parts
# 0  [santhosh, gmail.com]
# 1      [raju, yahoo.com]
# 2     [kiran, gmail.com]
# ...

# %%
df["startswithv"] = df["city"].str.startswith("V")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length  is_mail  endswith  \
# 0  9876543210      PRD-101  12-Jan-2024           19     True      True
# 1  9123456789      PRD-202  05-Feb-2024           10    False      True
# 2  9988776655      PRD-303  18-Mar-2024           13     True      True
# 3  9871234567      PRD-404  22-Apr-2024           13    False      True
# 4  9012345678      PRD-505  30-May-2024           12     True      True
#
#              email_parts  startswithv
# 0  [santhosh, gmail.com]         True
# ...

# %%
df["email_parts"] = df["email"].str.split("@").str[0]
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length  is_mail  endswith  \
# 0  9876543210      PRD-101  12-Jan-2024           19     True      True
# 1  9123456789      PRD-202  05-Feb-2024           10    False      True
# 2  9988776655      PRD-303  18-Mar-2024           13     True      True
# 3  9871234567      PRD-404  22-Apr-2024           13    False      True
# 4  9012345678      PRD-505  30-May-2024           12     True      True
#
#   email_parts  startswithv
# 0    santhosh         True
# 1        raju        False
# ...

# %%
df["vity_code"]=df["city"].str[:3]
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length  is_mail  endswith  \
# 0  9876543210      PRD-101  12-Jan-2024           19     True      True
# 1  9123456789      PRD-202  05-Feb-2024           10    False      True
# 2  9988776655      PRD-303  18-Mar-2024           13     True      True
# 3  9871234567      PRD-404  22-Apr-2024           13    False      True
# 4  9012345678      PRD-505  30-May-2024           12     True      True
#
#   email_parts  startswithv vity_code
# 0    santhosh         True       VIJ
# ...

# %%
df["is_numeric"]=df["phone"].astype(str).str.isnumeric()
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length  is_mail  endswith  \
# 0  9876543210      PRD-101  12-Jan-2024           19     True      True
# 1  9123456789      PRD-202  05-Feb-2024           10    False      True
# 2  9988776655      PRD-303  18-Mar-2024           13     True      True
# 3  9871234567      PRD-404  22-Apr-2024           13    False      True
# 4  9012345678      PRD-505  30-May-2024           12     True      True
#
#   email_parts  startswithv vity_code  is_numeric
# 0    santhosh         True       VIJ        True
# ...

# %%
df["product_code"]=df["product_code"].str.removeprefix("PRD-")
df
# Out:
#          customer_name               email        city purchase_amount  \
# 0    Santhosh Chevuri   santhosh@gmail.com  VIJAYAWADA            1000
# 1           Raju Kumar      raju@yahoo.com   HYDERABAD             250
# 2          Kiran Reddy     kiran@gmail.com      VIZAG             3500
# 3        Suresh Babu    suresh@outlook.com      GUNTUR            1200
# 4         Lakshmi Devi   lakshmi@gmail.com    TIRUPATI             750
#
#         phone product_code    join_date  name_length  is_mail  endswith  \
# 0  9876543210          101  12-Jan-2024           19     True      True
# 1  9123456789          202  05-Feb-2024           10    False      True
# 2  9988776655          303  18-Mar-2024           13     True      True
# 3  9871234567          404  22-Apr-2024           13    False      True
# 4  9012345678          505  30-May-2024           12     True      True
#
#   email_parts  startswithv vity_code  is_numeric
# 0    santhosh         True       VIJ        True
# ...

# %% [markdown]
# #**Task** Five

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets for datascience/bank_customer_data (1).csv")
df

# %%
df["customer_name"] = df["customer_name"].str.title()
df

# %%
df["email"]=df["email"].str.lower()
df

# %%
df["bank_name"]=df["bank_name"].str.upper()
df

# %%
df["account_type"]=df["account_type"].str.upper()
df

# %%
df['balance'] = df['balance'].str.replace('Rs', '', regex=False)
df['balance'] = df['balance'].str.replace('$', '', regex=False)
df['balance'] = df['balance'].str.replace(',', '', regex=False)
df['balance'] = df['balance'].str.strip()
df

# %%
df["balance"]=df["balance"].astype(int)
df

# %%
df["username"]=df["email"].str.split("@").str[0]
df

# %%
df["domain"]=df["email"].str.split("@").str[1]
df

# %%
df["branch_code"]=df["branch_city"].str[:3].str.upper()
df

# %%
df['account_number'] = df['account_number'].str.replace('ACC-', '', regex=False)
df
